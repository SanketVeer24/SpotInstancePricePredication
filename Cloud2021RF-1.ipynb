# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from matplotlib import rcParams

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
data_path = '/content/drive/MyDrive/Colab Notebooks/Cloud/2021_m2_4xlarge_us_east_1a'
data = pd.read_csv(data_path, delimiter=',', header=None, low_memory=False)

# %%
data
# Out:
#            0                          1           2     3      4    5     6  \
# 0      Price                       Date          OS  year  month  day  hour
# 1      0.098  2021-07-06 14:18:48-07:00  Linux/UNIX  2021      7    6    14
# 2      0.098  2021-05-19 12:30:31-07:00  Linux/UNIX  2021      5   19    12
# 3     0.3227  2021-11-18 22:14:42-08:00  Linux/UNIX  2021     11   18    22
# 4      0.098  2021-06-22 07:42:30-07:00  Linux/UNIX  2021      6   22     7
# ...      ...                        ...         ...   ...    ...  ...   ...
# 1580  0.6793  2021-09-20 16:00:55-07:00  Linux/UNIX  2021      9   20    16
# 1581  0.3541  2021-09-14 04:54:31-07:00  Linux/UNIX  2021      9   14     4
# 1582  0.1999  2021-09-08 20:48:48-07:00  Linux/UNIX  2021      9    8    20
# 1583  0.5403  2021-11-14 13:43:59-08:00  Linux/UNIX  2021     11   14    13
# 1584  0.7737  2021-09-21 16:15:06-07:00  Linux/UNIX  2021      9   21    16
#
#            7       8
# 0     minute  second
# 1         18      48
# 2         30      31
# 3         14      42
# 4         42      30
# ...      ...     ...
# 1580       0      55
# 1581      54      31
# 1582      48      48
# 1583      43      59
# 1584      15       6
#
# [1585 rows x 9 columns]

# %% [markdown]
# # New Section

# %%
# data.head

# %%
data.columns = ['Price', 'Date','OS','year', 'month','day', 'hour', 'minute', 'second']

# %%
# data.head

# %%
data = data.drop(0)

# %%
# data = data.sample(frac=1, random_state=42)

# %%
# data.to_csv('/content/drive/MyDrive/Colab Notebooks/Cloud/2021s_c1_xlarge_us_east_1d', index=False, header = True)

# %%
data
# Out:
#        Price                       Date          OS  year month day hour  \
# 1      0.098  2021-07-06 14:18:48-07:00  Linux/UNIX  2021     7   6   14
# 2      0.098  2021-05-19 12:30:31-07:00  Linux/UNIX  2021     5  19   12
# 3     0.3227  2021-11-18 22:14:42-08:00  Linux/UNIX  2021    11  18   22
# 4      0.098  2021-06-22 07:42:30-07:00  Linux/UNIX  2021     6  22    7
# 5      0.098  2021-02-20 14:18:18-08:00  Linux/UNIX  2021     2  20   14
# ...      ...                        ...         ...   ...   ...  ..  ...
# 1580  0.6793  2021-09-20 16:00:55-07:00  Linux/UNIX  2021     9  20   16
# 1581  0.3541  2021-09-14 04:54:31-07:00  Linux/UNIX  2021     9  14    4
# 1582  0.1999  2021-09-08 20:48:48-07:00  Linux/UNIX  2021     9   8   20
# 1583  0.5403  2021-11-14 13:43:59-08:00  Linux/UNIX  2021    11  14   13
# 1584  0.7737  2021-09-21 16:15:06-07:00  Linux/UNIX  2021     9  21   16
#
#      minute second
# 1        18     48
# 2        30     31
# 3        14     42
# 4        42     30
# 5        18     18
# ...     ...    ...
# 1580      0     55
# 1581     54     31
# 1582     48     48
# 1583     43     59
# 1584     15      6
#
# [1584 rows x 9 columns]

# %%
data['Price'].value_counts()
# Out:
# 0.098     651
# 0.98      209
# 0.1186     11
# 0.3219     10
# 0.6016     10
#          ...
# 0.2466      1
# 0.6194      1
# 0.1513      1
# 0.103       1
# 0.2309      1
# Name: Price, Length: 236, dtype: int64

# %%
data.shape
# Out:
# (1584, 9)

# %%
data.isna().any(axis=1).sum()
# Out:
# 0

# %%
data.dropna(axis=1)
# Out:
#        Price                       Date          OS  year month day hour  \
# 1      0.098  2021-07-06 14:18:48-07:00  Linux/UNIX  2021     7   6   14
# 2      0.098  2021-05-19 12:30:31-07:00  Linux/UNIX  2021     5  19   12
# 3     0.3227  2021-11-18 22:14:42-08:00  Linux/UNIX  2021    11  18   22
# 4      0.098  2021-06-22 07:42:30-07:00  Linux/UNIX  2021     6  22    7
# 5      0.098  2021-02-20 14:18:18-08:00  Linux/UNIX  2021     2  20   14
# ...      ...                        ...         ...   ...   ...  ..  ...
# 1580  0.6793  2021-09-20 16:00:55-07:00  Linux/UNIX  2021     9  20   16
# 1581  0.3541  2021-09-14 04:54:31-07:00  Linux/UNIX  2021     9  14    4
# 1582  0.1999  2021-09-08 20:48:48-07:00  Linux/UNIX  2021     9   8   20
# 1583  0.5403  2021-11-14 13:43:59-08:00  Linux/UNIX  2021    11  14   13
# 1584  0.7737  2021-09-21 16:15:06-07:00  Linux/UNIX  2021     9  21   16
#
#      minute second
# 1        18     48
# 2        30     31
# 3        14     42
# 4        42     30
# 5        18     18
# ...     ...    ...
# 1580      0     55
# 1581     54     31
# 1582     48     48
# 1583     43     59
# 1584     15      6
#
# [1584 rows x 9 columns]

# %%
data_temp = data

# %%
data.describe()
# Out:
#         Price                       Date          OS  year month   day  hour  \
# count    1584                       1584        1584  1584  1584  1584  1584
# unique    236                        524           1     1    12    31    24
# top     0.098  2021-09-04 21:34:58-07:00  Linux/UNIX  2021     9    19    14
# freq      651                          7        1584  1584   480    65   447
#
#        minute second
# count    1584   1584
# unique     60     60
# top        18     49
# freq       60     60

# %%
data_y = data['Price']
data_x = data.drop(['Price'], axis=1)

# %%
data_x
# Out:
#                            Date          OS  year month day hour minute second
# 1     2021-07-06 14:18:48-07:00  Linux/UNIX  2021     7   6   14     18     48
# 2     2021-05-19 12:30:31-07:00  Linux/UNIX  2021     5  19   12     30     31
# 3     2021-11-18 22:14:42-08:00  Linux/UNIX  2021    11  18   22     14     42
# 4     2021-06-22 07:42:30-07:00  Linux/UNIX  2021     6  22    7     42     30
# 5     2021-02-20 14:18:18-08:00  Linux/UNIX  2021     2  20   14     18     18
# ...                         ...         ...   ...   ...  ..  ...    ...    ...
# 1580  2021-09-20 16:00:55-07:00  Linux/UNIX  2021     9  20   16      0     55
# 1581  2021-09-14 04:54:31-07:00  Linux/UNIX  2021     9  14    4     54     31
# 1582  2021-09-08 20:48:48-07:00  Linux/UNIX  2021     9   8   20     48     48
# 1583  2021-11-14 13:43:59-08:00  Linux/UNIX  2021    11  14   13     43     59
# 1584  2021-09-21 16:15:06-07:00  Linux/UNIX  2021     9  21   16     15      6
#
# [1584 rows x 8 columns]

# %%
data_y
# Out:
# 1        0.098
# 2        0.098
# 3       0.3227
# 4        0.098
# 5        0.098
#          ...
# 1580    0.6793
# 1581    0.3541
# 1582    0.1999
# 1583    0.5403
# 1584    0.7737
# Name: Price, Length: 1584, dtype: object

# %%
data_y = data_y.reset_index()

# %%
data_y
# Out:
#       index   Price
# 0         1   0.098
# 1         2   0.098
# 2         3  0.3227
# 3         4   0.098
# 4         5   0.098
# ...     ...     ...
# 1579   1580  0.6793
# 1580   1581  0.3541
# 1581   1582  0.1999
# 1582   1583  0.5403
# 1583   1584  0.7737
#
# [1584 rows x 2 columns]

# %%
data_x = data_x.reset_index()

# %%
data_x.index[0]
# Out:
# 0

# %%
data_y = data_y.drop(['index'], axis=1)

# %%
data_y
# Out:
#        Price
# 0      0.098
# 1      0.098
# 2     0.3227
# 3      0.098
# 4      0.098
# ...      ...
# 1579  0.6793
# 1580  0.3541
# 1581  0.1999
# 1582  0.5403
# 1583  0.7737
#
# [1584 rows x 1 columns]

# %%
data_x
# Out:
#       index                       Date          OS  year month day hour  \
# 0         1  2021-07-06 14:18:48-07:00  Linux/UNIX  2021     7   6   14
# 1         2  2021-05-19 12:30:31-07:00  Linux/UNIX  2021     5  19   12
# 2         3  2021-11-18 22:14:42-08:00  Linux/UNIX  2021    11  18   22
# 3         4  2021-06-22 07:42:30-07:00  Linux/UNIX  2021     6  22    7
# 4         5  2021-02-20 14:18:18-08:00  Linux/UNIX  2021     2  20   14
# ...     ...                        ...         ...   ...   ...  ..  ...
# 1579   1580  2021-09-20 16:00:55-07:00  Linux/UNIX  2021     9  20   16
# 1580   1581  2021-09-14 04:54:31-07:00  Linux/UNIX  2021     9  14    4
# 1581   1582  2021-09-08 20:48:48-07:00  Linux/UNIX  2021     9   8   20
# 1582   1583  2021-11-14 13:43:59-08:00  Linux/UNIX  2021    11  14   13
# 1583   1584  2021-09-21 16:15:06-07:00  Linux/UNIX  2021     9  21   16
#
#      minute second
# 0        18     48
# 1        30     31
# 2        14     42
# 3        42     30
# 4        18     18
# ...     ...    ...
# 1579      0     55
# 1580     54     31
# 1581     48     48
# 1582     43     59
# 1583     15      6
#
# [1584 rows x 9 columns]

# %%
data_x = data_x.drop(['Date','OS','index'], axis=1)

# %%
data_x
# Out:
#       year month day hour minute second
# 0     2021     7   6   14     18     48
# 1     2021     5  19   12     30     31
# 2     2021    11  18   22     14     42
# 3     2021     6  22    7     42     30
# 4     2021     2  20   14     18     18
# ...    ...   ...  ..  ...    ...    ...
# 1579  2021     9  20   16      0     55
# 1580  2021     9  14    4     54     31
# 1581  2021     9   8   20     48     48
# 1582  2021    11  14   13     43     59
# 1583  2021     9  21   16     15      6
#
# [1584 rows x 6 columns]

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, Y_train, Y_test = train_test_split(data_x, data_y, test_size = 0.3, random_state=1, shuffle = False)

# %%
from sqlalchemy.sql.operators import not_endswith_op
from sklearn.ensemble import RandomForestRegressor
from sklearn.metrics import mean_squared_error
from sklearn.metrics import mean_absolute_error
from sklearn.metrics import mean_absolute_percentage_error
from sklearn.metrics import r2_score
from sklearn.metrics import accuracy_score

import matplotlib.pyplot as plt
from sklearn.utils import shuffle
# %matplotlib inline
trainAcc = []
testAcc = []

clf = RandomForestRegressor(n_estimators=200, max_depth=10, min_samples_leaf=2,
                                     random_state=1,
                                     n_jobs=-1,min_samples_split=10)
clf.fit(X_train, np.array(Y_train).ravel())
print(f"Score {clf.score(X_train,np.array(Y_train).ravel() )}")
y_pred_test = clf.predict(X_test)
y_pred_train = clf.predict(X_train)
testAcc.append(mean_absolute_percentage_error(Y_test, y_pred_test))
MAE_test = mean_absolute_error(Y_test, y_pred_test)
MAPE_test = mean_absolute_percentage_error(Y_test, y_pred_test)
mse_test = mean_squared_error(Y_test, y_pred_test)
rmse_test = np.sqrt(mse_test)
r2_test = r2_score(Y_test, y_pred_test)

print(f"r2 Test: {r2_test}")
print(f"mse Test: {mse_test}")
print(f"rmse Test: {rmse_test}")
print(f"MAPE Test: {MAPE_test}")
print(f"MAE Test: {MAE_test}")
# Out:
# Score 0.9916297026562797
# r2 Test: 0.9855089111037377
# mse Test: 0.001503057019438934
# rmse Test: 0.038769279325761706
# MAPE Test: 0.06532679557419539
# MAE Test: 0.016802929565223085

# %%
Y_test_array = Y_test['Price'].values
tested_data_index = Y_test.iloc[:, :0]
Y_test_data = pd.DataFrame(Y_test, index=tested_data_index.index)
dfilter = pd.DataFrame(index=tested_data_index.index)
filteredList = dfilter.index.tolist();
i = 0
j = 0
dictionary_Predict_value = {}
dictionary_Test_value = {}

for val in y_pred_test:
  dictionary_Predict_value[filteredList[i]]=val
  i=i+1
for val in Y_test['Price'].values:
  dictionary_Test_value[filteredList[j]]=float(val)
  j=j+1

# %%
Y_test_data = pd.DataFrame(Y_test, index=Y_test.index)
Y_test_index = Y_test_data[Y_test_data['Price'].notna()]
linux_values = pd.DataFrame(index=Y_test_index.index).index.tolist()
test_array_ = []
pred_array_ = []
x_values = []
for key in linux_values:
   test_array_.append(dictionary_Test_value[key])
   pred_array_.append("{:.4f}".format(dictionary_Predict_value[key]))
   x_values.append(data_temp.iloc[key]['Date'])

x_lables = np.arange(len(x_values))
test_array_values = [float(value) for value in test_array_]
pred_array_values = [float(value) for value in pred_array_]
rcParams['figure.figsize'] = 22, 5
  # Plot the data
plt.plot(pred_array_values[0:100])

plt.plot(test_array_values[0:100])

plt.ylim(0, 1.2)
#plt.yticks([0,0.05,0.10,0.15,0.20,.25,.30,.35,.40,.45,.50,.55,.60])
   #plt.xlim(0, 150)
plt.xticks(x_lables[0:100], x_values[0:100], rotation=90)
plt.legend(['Predicted','Actual'])
  # Add labels and legend
plt.ylabel('Y-axis Label')
plt.xlabel("------Date-------")
  # Show the plot
plt.show();

# %%
Y_test_array = Y_test['Price'].values

# %%
Y_test_array = np.array(Y_test_array)

# %%
array = Y_test_array.tolist()

# %%
type(y_pred_test)
# Out:
# numpy.ndarray

# %%
test_range = Y_test['Price'].values

# %%
test_array = [float(value) for value in test_range.tolist()]

# %%
# x_values = np.arange(len(Y_test_array))
# rcParams['figure.figsize'] = 22, 5
# # Plot the data
# plt.plot(x_values[0:400], test_array[0:400], label='Y Test')
# plt.plot(x_values[0:400], y_pred_test[0:400],label='Y Pred Test')

# # Add labels and legend
# plt.ylabel('Y-axis Label')
# plt.legend()

# # Show the plot
# plt.show()

# %%
files=['/content/drive/MyDrive/Colab Notebooks/Cloud/2021_m2_4xlarge_us_east_1a','/content/drive/MyDrive/Colab Notebooks/Cloud/2021_m2_4xlarge_us_east_1b',
       '/content/drive/MyDrive/Colab Notebooks/Cloud/2021_m2_4xlarge_us_east_1c',
       '/content/drive/MyDrive/Colab Notebooks/Cloud/2021_m2_4xlarge_us_east_1d']
for fileName in files:
  data_path = fileName
  data = pd.read_csv(data_path, delimiter=',', header=None, low_memory=False)
  data.columns = ['Price', 'Date','OS','year', 'month','day', 'hour', 'minute', 'second']
  data = data.drop(0)
  data.isna().any(axis=1).sum()
  data_temp = data
  data.dropna(axis=1)
  data_y = data['Price']
  data_x = data.drop(['Price'], axis=1)
  data_y = data_y.reset_index()
  data_x = data_x.reset_index()
  data_y = data_y.drop(['index'], axis=1)
  data_x = data_x.drop(['Date','OS','index'], axis=1)
  X_train, X_test, Y_train, Y_test = train_test_split(data_x, data_y, test_size = 0.3, random_state=1, shuffle = False)
  trainAcc = []
  testAcc = []

  clf = RandomForestRegressor(n_estimators=200, max_depth=10, min_samples_leaf=2,
                                      random_state=1,
                                      n_jobs=-1,min_samples_split=10)
  clf.fit(X_train, np.array(Y_train).ravel())
  # print(f"Score {clf.score(X_train,np.array(Y_train).ravel() )}")
  y_pred_test = clf.predict(X_test)
  y_pred_train = clf.predict(X_train)
  testAcc.append(mean_absolute_percentage_error(Y_test, y_pred_test))
  MAE_test = mean_absolute_error(Y_test, y_pred_test)
  MAPE_test = mean_absolute_percentage_error(Y_test, y_pred_test)
  mse_test = mean_squared_error(Y_test, y_pred_test)
  rmse_test = np.sqrt(mse_test)
  r2_test = r2_score(Y_test, y_pred_test)
  print((accuracy_score(Y_test, y_pred_test))}")
  print("\n\n")
  # print(f"r2 Test: {r2_test}")
  # print(f"mse Test: {mse_test}")
  # print(f"rmse Test: {rmse_test}")
  print(f"MAPE Test: {MAPE_test}")
  # print(f"MAE Test: {MAE_test}")
  Y_test_array = Y_test['Price'].values
  Y_test_array = np.array(Y_test_array)
  test_range = Y_test['Price'].values
  x_values = np.arange(len(Y_test_array))
  test_array = [float(value) for value in test_range.tolist()]
  Y_test_array = Y_test['Price'].values

  tested_data_index = Y_test.iloc[:, :0]
  Y_test_data = pd.DataFrame(Y_test, index=tested_data_index.index)
  dfilter = pd.DataFrame(index=tested_data_index.index)
  filteredList = dfilter.index.tolist();
  i = 0
  j = 0
  dictionary_Predict_value = {}
  dictionary_Test_value = {}

  for val in y_pred_test:
    dictionary_Predict_value[filteredList[i]]=val
    i=i+1
  for val in Y_test['Price'].values:
    dictionary_Test_value[filteredList[j]]=float(val)
    j=j+1

  Y_test_data = pd.DataFrame(Y_test, index=Y_test.index)
  Y_test_index = Y_test_data[Y_test_data['Price'].notna()]
  linux_values = pd.DataFrame(index=Y_test_index.index).index.tolist()
  test_array_ = []
  pred_array_ = []
  x_values = []
  for key in linux_values:
    test_array_.append(dictionary_Test_value[key])
    pred_array_.append("{:.4f}".format(dictionary_Predict_value[key]))
    x_values.append(data_temp.iloc[key]['Date'])

  x_lables = np.arange(len(x_values))
  test_array_values = [float(value) for value in test_array_]
  pred_array_values = [float(value) for value in pred_array_]
  rcParams['figure.figsize'] = 22, 5
    # Plot the data
  plt.plot(pred_array_values[0:100])

  plt.plot(test_array_values[0:100])

  plt.ylim(0, 1.0)
  # plt.yticks([0,0.05,0.10,0.15,0.20,.25,.30,.35,.40,.45,.50,.55,.60])
    #plt.xlim(0, 150)
  plt.xticks(x_lables[0:100], x_values[0:100], rotation=90)
  plt.legend(['Predicted values','Actual values'])
    # Add labels and legend
  plt.ylabel('Prices')
  plt.xlabel("----------------------------Date----------------------------")
  plt.title(fileName.split('/')[-1])
    # Show the plot
  plt.show();

  # rcParams['figure.figsize'] = 22, 5
  # # Plot the data
  # plt.plot(x_values[0:400], test_array[0:400], label='Y Test')
  # plt.plot(x_values[0:400], y_pred_test[0:400],label='Y Pred Test')

  # # Add labels and legend
  # plt.ylabel('Price')
  # plt.legend()

  # # Show the plot
  # plt.show()
# Out:
# MAPE Test: 0.06532679557419539
# MAPE Test: 0.029676119623792296
# MAPE Test: 0.00929039673071766
# MAPE Test: 7.930164461608263e-15

# %%
# from sklearn.model_selection import GridSearchCV
# from sklearn.ensemble import RandomForestRegressor
# param_grid = {
#     'n_estimators': [200,300,400],  # Number of trees in the forest
#     'max_depth': [10,20,30],       # Maximum depth of each tree
#     'min_samples_split': [10,20,25], # Minimum number of samples required to split an internal node
#     'min_samples_leaf': [2,4, 8],   # Minimum number of samples required to be at a leaf node
#     'max_features': ['auto', 'sqrt'] # Maximum number of features to consider for the best split
# }
# rf_regressor = RandomForestRegressor(random_state=42)

# %%
# grid_search = GridSearchCV(estimator=rf_regressor, param_grid=param_grid, cv=5, scoring='neg_mean_squared_error', n_jobs=-1)

# grid_search.fit(X_train, Y_train)

# best_params = grid_search.best_params_
# best_estimator = grid_search.best_estimator_

# y_pred = best_estimator.predict(X_test)

# best_score = grid_search.best_score_
# r2 = r2_score(Y_test, y_pred)
# MAPE_test = mean_absolute_percentage_error(Y_test, y_pred_test)

# print(f'Best R2 Score: {r2}')
# print(f"MAPE Test: {MAPE_test}")
# print("Best Hyperparameters:", best_params)
# print("Best Negative Mean Squared Error:", best_score)
